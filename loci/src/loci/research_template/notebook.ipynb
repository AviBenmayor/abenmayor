# %% [markdown]
# # __RQ_ID__ — __TITLE__
#
# Scaffolded __DATE__ by `loci research new`. Ten fixed sections; fill each in order.

# %% [markdown]
# ## 0. Question
#
# State the question as asked (from QUESTION.md) and the version of the answer this
# run produces. No code in this cell — it is the frame for everything below.

# %% [markdown]
# ## 1. Data & provenance
#
# Load every input named in DATA-AUDIT.md from the warehouse (or state which are
# missing/blocked and cite the ticket). Record row counts and date ranges so the
# provenance of the panel below is auditable from the output alone.

# %%
# TODO: Data & provenance
pass

# %% [markdown]
# ## 2. Build panel
#
# Assemble the analysis panel at the unit of analysis QUESTION.md names.

# %%
# TODO: Build panel
pass

# %% [markdown]
# ## 3. Method
#
# State and implement the method (e.g. regime definition, model form, estimator).
# Compare against the alternate definition/method SEED.yaml calls for, if any.

# %%
# TODO: Method
pass

# %% [markdown]
# ## 4. Results
#
# The core result table/plot this RQ exists to produce.

# %%
# TODO: Results
pass

# %% [markdown]
# ## 5. Sensitivity
#
# How much the headline result moves under the alternate definition/threshold/
# specification named in SEED.yaml.

# %%
# TODO: Sensitivity
pass

# %% [markdown]
# ## 6. Drivers
#
# Ranked drivers of the outcome (e.g. hazard covariates), with any driver marked
# BLOCKED and its ticket id if the input isn't available yet.

# %%
# TODO: Drivers
pass

# %% [markdown]
# ## 7. Validation
#
# Run the validation plan ANSWER.md's Validation table commits to (backtest vs a
# naive baseline, domain-expert spot check, methodology review) — RUN inline or
# TICKETED with an id, matching ANSWER.md exactly.

# %%
# TODO: Validation
pass

# %% [markdown]
# ## 8. ANSWER (plain language)
#
# Restate ANSWER.md's Answer section here so the executed notebook is a
# self-contained artifact — copy it in after ANSWER.md is written, don't
# duplicate-author it.

# %% [markdown]
# ## 9. Caveats & next data
#
# What would change this answer, and which tickets would supply it. Mirrors
# ANSWER.md's Gaps → tickets section.
